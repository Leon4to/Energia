# %%
import pandas as pd

df = pd.read_csv("global-data-on-sustainable-energy.csv")
df
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %%
df.dropna(how = 'all')
df.isnull().sum()
# Out:
# Entity                                                                 0
# Year                                                                   0
# Access to electricity (% of population)                               10
# Access to clean fuels for cooking                                    169
# Renewable-electricity-generating-capacity-per-capita                 931
# Financial flows to developing countries (US $)                      2089
# Renewable energy share in the total final energy consumption (%)     194
# Electricity from fossil fuels (TWh)                                   21
# Electricity from nuclear (TWh)                                       126
# Electricity from renewables (TWh)                                     21
# Low-carbon electricity (% electricity)                                42
# Primary energy consumption per capita (kWh/person)                     0
# Energy intensity level of primary energy (MJ/$2017 PPP GDP)          207
# ...

# %%
df['Access to electricity (% of population)'].unique()
# Out:
# array([ 1.613591,  4.074574,  9.409158, ..., 45.572647, 46.781475,
#        52.74767 ])

# %%
df1 = pd.read_csv("clean_regional_data.csv")
df1
# Out:
#                           Country  Year  \
# 0     Africa Eastern and Southern  2000
# 1     Africa Eastern and Southern  2001
# 2     Africa Eastern and Southern  2002
# 3     Africa Eastern and Southern  2003
# 4     Africa Eastern and Southern  2004
# ...                           ...   ...
# 1003                        World  2016
# 1004                        World  2017
# 1005                        World  2018
# 1006                        World  2019
# 1007                        World  2020
#
#       Access to clean fuels and technologies for cooking (% of population)  \
# 0                                             11.580366
# 1                                             11.907943
# 2                                             12.285175
# 3                                             12.607641
# 4                                             12.990589
# ...                                                 ...
# 1003                                          65.005668
# ...

# %%
df2 = pd.read_csv("cleandata.csv")
df2
# Out:
#           Country  Year  \
# 0     Afghanistan  2000
# 1     Afghanistan  2001
# 2     Afghanistan  2002
# 3     Afghanistan  2003
# 4     Afghanistan  2004
# ...           ...   ...
# 4006     Zimbabwe  2016
# 4007     Zimbabwe  2017
# 4008     Zimbabwe  2018
# 4009     Zimbabwe  2019
# 4010     Zimbabwe  2020
#
#       Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                   6.7
# 1                                                   7.7
# 2                                                   8.8
# 3                                                  10.0
# 4                                                  11.1
# ...                                                 ...
# 4006                                               30.0
# 4007                                               29.8
# 4008                                               30.0
# 4009                                               30.2
# ...

# %%
df3 = pd.read_csv("cleandataTurkiye.csv")
df3
# Out:
#           Country  Year  \
# 0     Afghanistan  2000
# 1     Afghanistan  2001
# 2     Afghanistan  2002
# 3     Afghanistan  2003
# 4     Afghanistan  2004
# ...           ...   ...
# 4006     Zimbabwe  2016
# 4007     Zimbabwe  2017
# 4008     Zimbabwe  2018
# 4009     Zimbabwe  2019
# 4010     Zimbabwe  2020
#
#       Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                   6.7
# 1                                                   7.7
# 2                                                   8.8
# 3                                                  10.0
# 4                                                  11.1
# ...                                                 ...
# 4006                                               30.0
# 4007                                               29.8
# 4008                                               30.0
# 4009                                               30.2
# ...

# %%
df4 = pd.read_csv("new_data.csv")
df4
# Out:
#           Country  Year  \
# 0     Afghanistan  2000
# 1     Afghanistan  2001
# 2     Afghanistan  2002
# 3     Afghanistan  2003
# 4     Afghanistan  2004
# ...           ...   ...
# 5014        World  2016
# 5015        World  2017
# 5016        World  2018
# 5017        World  2019
# 5018        World  2020
#
#       Access to clean fuels and technologies for cooking (% of population)  \
# 0                                              6.700000
# 1                                              7.700000
# 2                                              8.800000
# 3                                             10.000000
# 4                                             11.100000
# ...                                                 ...
# 5014                                          65.005668
# 5015                                          66.321819
# 5016                                          67.696517
# 5017                                          68.921601
# ...
