# %%
import pandas as pd

df = pd.read_csv("Data-Tabelle 1.csv", sep=';')
df
# Out:
#        Year            Area          Variable  Generation (TWh)  \
# 0      2000         Austria            Fossil                16
# 1      2000         Austria              Coal                 6
# 2      2000         Austria         Hard Coal                 4
# 3      2000         Austria           Lignite                 1
# 4      2000         Austria               Gas                 8
# ...     ...             ...               ...               ...
# 10705  2020  United Kingdom         Bioenergy                35
# 10706  2020  United Kingdom  Other renewables                 0
# 10707  2020  United Kingdom        Production               305
# 10708  2020  United Kingdom       Net imports                18
# 10709  2020  United Kingdom            Demand               324
#
#        Share of production (%)  Change on last year (%)  \
# 0                         27.0                      NaN
# 1                         10.0                      NaN
# ...

# %%
df_country_overview = pd.read_csv("EER_2022_country_overview.csv")
df_country_overview
# Out:
#         country_name country_code  eu_member  year  generation_twh  \
# 0            Albania          ALB          0  1990            3.30
# 1            Albania          ALB          0  1991            3.82
# 2            Albania          ALB          0  1992            3.40
# 3            Albania          ALB          0  1993            3.53
# 4            Albania          ALB          0  1994            3.94
# ...              ...          ...        ...   ...             ...
# 1151  United Kingdom          GBR          0  2017          335.10
# 1152  United Kingdom          GBR          0  2018          330.50
# 1153  United Kingdom          GBR          0  2019          321.65
# 1154  United Kingdom          GBR          0  2020          307.46
# 1155  United Kingdom          GBR          0  2021          305.50
#
#       net_import_twh  demand_twh  demand_mwh_per_capita
# 0               0.21        3.51                  1.068
# ...

# %%
df_country_emissions = pd.read_csv("EER_2022_emissions.csv")
df_country_emissions
# Out:
#     country_name country_code  year  emissions_intensity_gco2_kwh  \
# 0        Austria          AUT  2000                           156
# 1        Austria          AUT  2001                           163
# 2        Austria          AUT  2002                           152
# 3        Austria          AUT  2003                           204
# 4        Austria          AUT  2004                           185
# ..           ...          ...   ...                           ...
# 589       Sweden          SWE  2017                            10
# 590       Sweden          SWE  2018                            11
# 591       Sweden          SWE  2019                            10
# 592       Sweden          SWE  2020                            10
# 593       Sweden          SWE  2021                            10
#
#      emissions_mtc02e
# 0                  10
# 1                  10
# 2                   9
# 3                  12
# 4                  12
# ..                ...
# ...

# %%
df_country_generation = pd.read_csv("EER_2022_generation.csv")
df_country_generation
# Out:
#          country_name country_code  eu_member  year fuel_code     fuel_desc  \
# 0             Albania          ALB          0  1990       BIO     Bioenergy
# 1             Albania          ALB          0  1990       GAS           Gas
# 2             Albania          ALB          0  1990  HARDCOAL     Hard Coal
# 3             Albania          ALB          0  1990     HYDRO         Hydro
# 4             Albania          ALB          0  1990   LIGNITE       Lignite
# ...               ...          ...        ...   ...       ...           ...
# 11541  United Kingdom          GBR          0  2021     HYDRO         Hydro
# 11542  United Kingdom          GBR          0  2021   NUCLEAR       Nuclear
# 11543  United Kingdom          GBR          0  2021   OTHFOSS  Other Fossil
# 11544  United Kingdom          GBR          0  2021     SOLAR         Solar
# 11545  United Kingdom          GBR          0  2021      WIND          Wind
#
# ...

# %%
df_country_net_flows = pd.read_csv("EER_2022_net_flows.csv")
df_country_net_flows
# Out:
#       year source_country_code target_country_code  net_flow_twh
# 0     2015                 ALB                 GRC         -0.47
# 1     2015                 ALB                 MNE         -1.14
# 2     2015                 AUT                 CHE          6.74
# 3     2015                 AUT                 CZE        -12.27
# 4     2015                 AUT                 DEU        -14.29
# ...    ...                 ...                 ...           ...
# 1067  2021                 UKR                 SVK         -1.72
# 1068  2021                 XKX                 ALB         -0.11
# 1069  2021                 XKX                 MKD          0.40
# 1070  2021                 XKX                 MNE          0.32
# 1071  2021                 XKX                 SRB         -1.25
#
# [1072 rows x 4 columns]

# %%
df1 = pd.read_csv("Statistical Review of World Energy Narrow File.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df1 = pd.read_csv("Statistical Review of World Energy Narrow File.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...
